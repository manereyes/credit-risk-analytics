# %%
from src.customer_generator import generate_customers


customers = generate_customers(
    n_customers=1000,
    random_state=42
)

print(customers.head())
# Out:
#   Customer_ID                   Segment  Age  Employment_Years  Annual_Income  \
# 0      C00001               High Income   37                 9      333470.80
# 1      C00002  Established Professional   35                15       84753.33
# 2      C00003  Established Professional   42                14       86883.93
# 3      C00004       Senior Professional   60                 7      139304.77
# 4      C00005               High Income   50                16      166738.31
#
#    Late_Payments  Credit_Utilization  Credit_History_Years  Credit_Mix  \
# 0              0               19.90                    11           3
# 1              0               50.55                    15           4
# 2              1               39.73                    15           1
# 3              2               36.71                    19           2
# 4              0               16.97                    20           3
#
#    Recent_Inquiries
# 0                 2
# 1                 1
# 2                 1
# 3                 0
# 4                 1

# %%
customers["Segment"].value_counts(normalize=True)
# Out:
# Segment
# Young Professional          0.311
# Established Professional    0.303
# Senior Professional         0.165
# Credit Builder              0.117
# High Income                 0.104
# Name: proportion, dtype: float64
